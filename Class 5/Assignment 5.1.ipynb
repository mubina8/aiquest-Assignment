# %%
price = [110, 105, 115, 120, 110, 130, 150, 100, 105]

# %%
price
# Out:
# [110, 105, 115, 120, 110, 130, 150, 100, 105]

# %%
import pandas as pd
data = pd.DataFrame(price,columns=['Price'])
data.head()
# Out:
#    Price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110

# %% [markdown]
# **Normalization / min max scaler**

# %%
#Manual Calculaton
min_price = data.Price.min()
max_price = data.Price.max()
data['Price_Norm_Manual'] = (data.Price - min_price) / (max_price - min_price)
data.head()
# Out:
#    Price  Price_Norm_Manual
# 0    110                0.2
# 1    105                0.1
# 2    115                0.3
# 3    120                0.4
# 4    110                0.2

# %%
#Calculation using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
mmx = MinMaxScaler()
data['Price_Norm_sklearn'] = mmx.fit_transform(data[['Price']])
data.head()
# Out:
#    Price  Price_Norm_Manual  Price_Norm_sklearn
# 0    110                0.2                 0.2
# 1    105                0.1                 0.1
# 2    115                0.3                 0.3
# 3    120                0.4                 0.4
# 4    110                0.2                 0.2

# %% [markdown]
# **Standardization / standard scaler**

# %%
#Manual Calculation
mean_price = data.Price.mean()
std = data.Price.std(ddof=0) # Standerd deviation for population

# %%
data['Price_Std_Manual'] = (data['Price'] - mean_price) / std

# %%
data.head()
# Out:
#    Price  Price_Norm_Manual  Price_Norm_sklearn  Price_Std_Manual
# 0    110                0.2                 0.2         -0.416356
# 1    105                0.1                 0.1         -0.757011
# 2    115                0.3                 0.3         -0.075701
# 3    120                0.4                 0.4          0.264954
# 4    110                0.2                 0.2         -0.416356

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
data['Price_Std_Sklearn'] = scaler.fit_transform(data[['Price']])

# %%
data.head()
# Out:
#    Price  Price_Norm_Manual  Price_Norm_sklearn  Price_Std_Manual  \
# 0    110                0.2                 0.2         -0.416356
# 1    105                0.1                 0.1         -0.757011
# 2    115                0.3                 0.3         -0.075701
# 3    120                0.4                 0.4          0.264954
# 4    110                0.2                 0.2         -0.416356
#
#    Price_Std_Sklearn
# 0          -0.416356
# 1          -0.757011
# 2          -0.075701
# 3           0.264954
# 4          -0.416356

# %% [markdown]
# **Log Transformation**

# %%
#Manual Calculation
import numpy as np
import math
data['Price_Log_Manual'] = np.log1p(data['Price'])

# %%
data.head()
# Out:
#    Price  Price_Norm_Manual  Price_Norm_sklearn  Price_Std_Manual  \
# 0    110                0.2                 0.2         -0.416356
# 1    105                0.1                 0.1         -0.757011
# 2    115                0.3                 0.3         -0.075701
# 3    120                0.4                 0.4          0.264954
# 4    110                0.2                 0.2         -0.416356
#
#    Price_Std_Sklearn  Price_Log_Manual  Price_Log_sklearn
# 0          -0.416356          4.709530           4.709530
# 1          -0.757011          4.663439           4.663439
# 2          -0.075701          4.753590           4.753590
# 3           0.264954          4.795791           4.795791
# 4          -0.416356          4.709530           4.709530

# %%
from sklearn.preprocessing import FunctionTransformer
transformer = FunctionTransformer(np.log1p)
data['Price_Log_sklearn'] = transformer.fit_transform(data[['Price']])

# %%
data.head()
# Out:
#    Price  Price_Norm_Manual  Price_Norm_sklearn  Price_Std_Manual  \
# 0    110                0.2                 0.2         -0.416356
# 1    105                0.1                 0.1         -0.757011
# 2    115                0.3                 0.3         -0.075701
# 3    120                0.4                 0.4          0.264954
# 4    110                0.2                 0.2         -0.416356
#
#    Price_Std_Sklearn  Price_Log_Manual  Price_Log_sklearn
# 0          -0.416356          4.700480           4.709530
# 1          -0.757011          4.653960           4.663439
# 2          -0.075701          4.744932           4.753590
# 3           0.264954          4.787492           4.795791
# 4          -0.416356          4.700480           4.709530

# %% [markdown]
# **Robust Scaler**

# %%
#Manual
import statistics
Median = statistics.median(data['Price'])
per75 = np.percentile(data['Price'], 75)
per25 = np.percentile(data['Price'],25)
data['Price_RS_Manual'] = (data['Price'] - Median) / (per75 - per25)

# %%
data.head()
# Out:
#    Price  Price_Norm_Manual  Price_Norm_sklearn  Price_Std_Manual  \
# 0    110                0.2                 0.2         -0.416356
# 1    105                0.1                 0.1         -0.757011
# 2    115                0.3                 0.3         -0.075701
# 3    120                0.4                 0.4          0.264954
# 4    110                0.2                 0.2         -0.416356
#
#    Price_Std_Sklearn  Price_Log_Manual  Price_Log_sklearn  Price_RS_Manual
# 0          -0.416356          4.709530           4.709530         0.000000
# 1          -0.757011          4.663439           4.663439        -0.333333
# 2          -0.075701          4.753590           4.753590         0.333333
# 3           0.264954          4.795791           4.795791         0.666667
# 4          -0.416356          4.709530           4.709530         0.000000

# %%
from sklearn.preprocessing import RobustScaler
RS = RobustScaler()
data['Price_RS_sklearn'] = RS.fit_transform(data[['Price']])

# %%
data.head()
# Out:
#    Price  Price_Norm_Manual  Price_Norm_sklearn  Price_Std_Manual  \
# 0    110                0.2                 0.2         -0.416356
# 1    105                0.1                 0.1         -0.757011
# 2    115                0.3                 0.3         -0.075701
# 3    120                0.4                 0.4          0.264954
# 4    110                0.2                 0.2         -0.416356
#
#    Price_Std_Sklearn  Price_Log_Manual  Price_Log_sklearn  Price_RS_Manual  \
# 0          -0.416356          4.709530           4.709530         0.000000
# 1          -0.757011          4.663439           4.663439        -0.333333
# 2          -0.075701          4.753590           4.753590         0.333333
# 3           0.264954          4.795791           4.795791         0.666667
# 4          -0.416356          4.709530           4.709530         0.000000
#
#    Price_RS_sklearn
# 0          0.000000
# 1         -0.333333
# 2          0.333333
# 3          0.666667
# 4          0.000000

# %% [markdown]
# **Max Absolute Scaler**

# %%
#Manual Calculation
Max_price = data.Price.max()
data['Price_MAS_Manual'] = data['Price'] / Max_price

# %%
data.head()
# Out:
#    Price  Price_Norm_Manual  Price_Norm_sklearn  Price_Std_Manual  \
# 0    110                0.2                 0.2         -0.416356
# 1    105                0.1                 0.1         -0.757011
# 2    115                0.3                 0.3         -0.075701
# 3    120                0.4                 0.4          0.264954
# 4    110                0.2                 0.2         -0.416356
#
#    Price_Std_Sklearn  Price_Log_Manual  Price_Log_sklearn  Price_RS_Manual  \
# 0          -0.416356          4.709530           4.709530         0.000000
# 1          -0.757011          4.663439           4.663439        -0.333333
# 2          -0.075701          4.753590           4.753590         0.333333
# 3           0.264954          4.795791           4.795791         0.666667
# 4          -0.416356          4.709530           4.709530         0.000000
#
#    Price_RS_sklearn  Price_MAS_Manual
# 0          0.000000          0.733333
# 1         -0.333333          0.700000
# 2          0.333333          0.766667
# 3          0.666667          0.800000
# 4          0.000000          0.733333

# %%
from sklearn.preprocessing import MaxAbsScaler
mx = MaxAbsScaler()
data['Price_MAS_sklearn'] = mx.fit_transform(data[['Price']])

# %%
data.head()
# Out:
#    Price  Price_Norm_Manual  Price_Norm_sklearn  Price_Std_Manual  \
# 0    110                0.2                 0.2         -0.416356
# 1    105                0.1                 0.1         -0.757011
# 2    115                0.3                 0.3         -0.075701
# 3    120                0.4                 0.4          0.264954
# 4    110                0.2                 0.2         -0.416356
#
#    Price_Std_Sklearn  Price_Log_Manual  Price_Log_sklearn  Price_RS_Manual  \
# 0          -0.416356          4.709530           4.709530         0.000000
# 1          -0.757011          4.663439           4.663439        -0.333333
# 2          -0.075701          4.753590           4.753590         0.333333
# 3           0.264954          4.795791           4.795791         0.666667
# 4          -0.416356          4.709530           4.709530         0.000000
#
#    Price_RS_sklearn  Price_MAS_Manual  Price_MAS_sklearn
# 0          0.000000          0.733333           0.733333
# 1         -0.333333          0.700000           0.700000
# 2          0.333333          0.766667           0.766667
# 3          0.666667          0.800000           0.800000
# 4          0.000000          0.733333           0.733333

# %%
data.to_excel('Transformed_Price_Data.xlsx', index=False)
